# %%
import decimal
from time import perf_counter
import torch
import numpy as np
import matplotlib.pyplot as plt

import torchvision.transforms.functional as F
from torchvision.models import alexnet, AlexNet_Weights, resnet101, ResNet101_Weights, densenet121, DenseNet121_Weights

# %%
# !rm -rf OID/Dataset/train/
# !git clone https://github.com/EscVM/OIDv4_ToolKit.git
# !pip install -r ./OIDv4_ToolKit/requirements.txt
# !python ./OIDv4_ToolKit/main.py downloader --classes Fruit --type_csv train --limit 50 --multiclasses 1 -y
# Out:
# fatal: destination path 'OIDv4_ToolKit' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 1)) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 2)) (1.21.6)
# Requirement already satisfied: awscli in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 3)) (1.27.50)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 5)) (1.26.14)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 7)) (4.64.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.8/dist-packages (from -r ./OIDv4_ToolKit/requirements.txt (line 9)) (4.6.0.66)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas->-r ./OIDv4_ToolKit/requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas->-r ./OIDv4_ToolKit/requirements.txt (line 1)) (2022.7)
# Requirement already satisfied: PyYAML<5.5,>=3.10 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (5.4.1)
# Requirement already satisfied: colorama<0.4.5,>=0.2.5 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (0.4.4)
# Requirement already satisfied: botocore==1.29.50 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (1.29.50)
# Requirement already satisfied: docutils<0.17,>=0.10 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (0.16)
# Requirement already satisfied: s3transfer<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (0.6.0)
# Requirement already satisfied: rsa<4.8,>=3.1.2 in /usr/local/lib/python3.8/dist-packages (from awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (4.7.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.8/dist-packages (from botocore==1.29.50->awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (1.0.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas->-r ./OIDv4_ToolKit/requirements.txt (line 1)) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<4.8,>=3.1.2->awscli->-r ./OIDv4_ToolKit/requirements.txt (line 3)) (0.4.8)
#
# 		   ___   _____  ______            _    _
# 		 .'   `.|_   _||_   _ `.         | |  | |
# 		/  .-.  \ | |    | | `. \ _   __ | |__| |_
# 		| |   | | | |    | |  | |[ \ [  ]|____   _|
# 		\  `-'  /_| |_  _| |_.' / \ \/ /     _| |_
# 		 `.___.'|_____||______.'   \__/     |_____|
#
#
#              _____                    _                 _
#             (____ \                  | |               | |
#              _   \ \ ___  _ _ _ ____ | | ___   ____  _ | | ____  ____
#             | |   | / _ \| | | |  _ \| |/ _ \ / _  |/ || |/ _  )/ ___)
#             | |__/ / |_| | | | | | | | | |_| ( ( | ( (_| ( (/ /| |
#             |_____/ \___/ \____|_| |_|_|\___/ \_||_|\____|\____)_|
#
#
#     [INFO] | Downloading ['Fruit'] together.
#
# Fruit
#     [INFO] | Downloading train images.
#     [INFO] | [INFO] Found 5283 online images for train.
#     [INFO] | Limiting to 50 images.
#     [INFO] | Download of 50 images in train.
# 100% 50/50 [00:32<00:00,  1.52it/s]
#     [INFO] | Done!
#     [INFO] | Creating labels for Fruit of train.
#     [INFO] | Labels creation completed.

# %%
alexnet = alexnet(AlexNet_Weights.DEFAULT).eval()
resnet101 = resnet101(ResNet101_Weights.DEFAULT).eval()
densenet121 = densenet121(DenseNet121_Weights.DEFAULT).eval()
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'weights' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# Downloading: "https://download.pytorch.org/models/densenet121-a639ec97.pth" to /root/.cache/torch/hub/checkpoints/densenet121-a639ec97.pth
#   0%|          | 0.00/30.8M [00:00<?, ?B/s]

# %%
from os import listdir
from os.path import isfile, join

MYPATH = 'OID/Dataset/train/'
lables = [f for f in listdir(MYPATH) if not isfile(join(MYPATH, f))]

data_images = []
for l in lables:
  for d in listdir(join(MYPATH, l)):
    if join(MYPATH, l, d).endswith('.jpg'):
      data_images.append(join(MYPATH, l, d))

print(data_images)
# Out:
# ['OID/Dataset/train/Fruit/659cd10bca70b317.jpg', 'OID/Dataset/train/Fruit/9edeea515cf89b2a.jpg', 'OID/Dataset/train/Fruit/31fffb3611ffa66b.jpg', 'OID/Dataset/train/Fruit/cff2073b6a9dfd40.jpg', 'OID/Dataset/train/Fruit/3d81c7d8acab67e2.jpg', 'OID/Dataset/train/Fruit/a5b53097a76d4fcf.jpg', 'OID/Dataset/train/Fruit/a7f4b96f07487cb3.jpg', 'OID/Dataset/train/Fruit/baceff9660f9973d.jpg', 'OID/Dataset/train/Fruit/026cbd2b207902fa.jpg', 'OID/Dataset/train/Fruit/eb25a2dd759fca6b.jpg', 'OID/Dataset/train/Fruit/2ca536d7496edf51.jpg', 'OID/Dataset/train/Fruit/bc293aa5a210e5a9.jpg', 'OID/Dataset/train/Fruit/fe03f065bc1f0719.jpg', 'OID/Dataset/train/Fruit/e43d4689076623ec.jpg', 'OID/Dataset/train/Fruit/8c2c839ca590477b.jpg', 'OID/Dataset/train/Fruit/ad9e88ea8944c05b.jpg', 'OID/Dataset/train/Fruit/1fffb1e23bb0f2fc.jpg', 'OID/Dataset/train/Fruit/a1e258cc4cf0016d.jpg', 'OID/Dataset/train/Fruit/3c19f3b03239dd45.jpg', 'OID/Dataset/train/Fruit/dedef72f7c731f30.jpg', 'OID/Dataset/train/Fruit/e27c0930a26f4aac.jpg', 'OID/Dataset/train/Fruit/d569f68f66184040.jpg', 'OID/Dataset/train/Fruit/03e97bcbdf4ab02b.jpg', 'OID/Dataset/train/Fruit/b124772f894f7b61.jpg', 'OID/Dataset/train/Fruit/0ba737d9bfd5ed93.jpg', 'OID/Dataset/train/Fruit/b7ebe165ea4059fb.jpg', 'OID/Dataset/train/Fruit/df1bc4bd13d1efef.jpg', 'OID/Dataset/train/Fruit/e23793ee474a41f5.jpg', 'OID/Dataset/train/Fruit/6157a32ad666d447.jpg', 'OID/Dataset/train/Fruit/a3d2c2e579f5cac8.jpg', 'OID/Dataset/train/Fruit/ef35d04b60776d99.jpg', 'OID/Dataset/train/Fruit/d4acb8ba045ba3a3.jpg', 'OID/Dataset/train/Fruit/646a175c8915b9d1.jpg', 'OID/Dataset/train/Fruit/0492e2f46ab6f8d7.jpg', 'OID/Dataset/train/Fruit/b7178de2a7d028a6.jpg', 'OID/Dataset/train/Fruit/c96ab96650678c3e.jpg', 'OID/Dataset/train/Fruit/694724b31a97a9f3.jpg', 'OID/Dataset/train/Fruit/b033124728e92c27.jpg', 'OID/Dataset/train/Fruit/e08dfc2ce2971830.jpg', 'OID/Dataset/train/Fruit/e6f1137e3ea856bd.jpg', 'OID/Dataset/train/Fruit/83886c78bc1074cd.jpg', 'OID/Dataset/train/Fruit/50a2bde8694536f0.jpg', 'OID/Dataset/train/Fruit/5dbc6cc22ea6c239.jpg', 'OID/Dataset/train/Fruit/a6e03c6128c79f19.jpg', 'OID/Dataset/train/Fruit/aedf7125a6aa5337.jpg', 'OID/Dataset/train/Fruit/f92d8ebbe2551816.jpg', 'OID/Dataset/train/Fruit/85bafc0bbebacb47.jpg', 'OID/Dataset/train/Fruit/060bd97018ab81e9.jpg', 'OID/Dataset/train/Fruit/24cf3d34d3f3b917.jpg', 'OID/Dataset/train/Fruit/34475762eb56e990.jpg']

# %%
def predict(weights, model, img):
    preprocess = weights.DEFAULT.transforms()
    batch = preprocess(img).unsqueeze(0)
    pred = model(batch).squeeze(0).softmax(0)
    val, index = torch.topk(pred, 5)
    for i in range(5):
        category_name = weights.DEFAULT.meta["categories"][index[i]]
        print(f"{category_name}: {100 * val[i]:.1f}%")

# %%
from torchvision.io import read_image

for data in data_images[:10]:
        print()
        img = read_image(data)
        print(data)
        print("AlexNet prediction")
        start = perf_counter()
        predict(AlexNet_Weights, alexnet, img)
        end = perf_counter()
        print("AlexNet frame time: " + str(end - start))
        print()
        print("ResNet101 prediction")
        start = perf_counter()
        predict(ResNet101_Weights, resnet101, img)
        end = perf_counter()
        print("ResNet101 frame time: " + str(end - start))
        print()
        print("DenseNet121 prediction")
        start = perf_counter()
        predict(DenseNet121_Weights, densenet121, img)
        end = perf_counter()
        print("DenseNet121 frame time: " + str(end - start))
        print()
# Out:
# OID/Dataset/train/Fruit/659cd10bca70b317.jpg
# AlexNet prediction
# banjo: 16.3%
# cello: 15.8%
# acoustic guitar: 10.6%
# wooden spoon: 9.5%
# ladle: 8.6%
# AlexNet frame time: 0.08038382699942304
#
# ResNet101 prediction
# jack-o'-lantern: 82.6%
# power drill: 0.2%
# swab: 0.2%
# vacuum: 0.1%
# EntleBucher: 0.1%
# ResNet101 frame time: 0.4043337719995179
#
# DenseNet121 prediction
# jack-o'-lantern: 93.2%
# soccer ball: 1.8%
# ocarina: 0.8%
# croquet ball: 0.8%
# pomegranate: 0.5%
# DenseNet121 frame time: 0.2023897830003989
#
#
# OID/Dataset/train/Fruit/9edeea515cf89b2a.jpg
# AlexNet prediction
# strawberry: 31.7%
# hip: 14.2%
# pomegranate: 13.6%
# thimble: 11.2%
# agaric: 6.9%
# AlexNet frame time: 0.06484755000019504
#
# ResNet101 prediction
# strawberry: 21.0%
# pomegranate: 13.8%
# tray: 4.9%
# ice cream: 3.9%
# saltshaker: 2.2%
# ResNet101 frame time: 0.44994420500006527
#
# DenseNet121 prediction
# strawberry: 84.1%
# hip: 2.7%
# trifle: 1.7%
# matchstick: 1.6%
# fig: 1.5%
# DenseNet121 frame time: 0.2766754680005761
#
#
# OID/Dataset/train/Fruit/31fffb3611ffa66b.jpg
# AlexNet prediction
# acorn: 21.9%
# maraca: 17.7%
# pencil sharpener: 9.5%
# pineapple: 5.8%
# pick: 4.7%
# AlexNet frame time: 0.08366489200034266
#
# ResNet101 prediction
# cucumber: 33.8%
# zucchini: 5.9%
# tray: 4.7%
# plate: 4.6%
# mushroom: 4.3%
# ResNet101 frame time: 0.5304224820001764
#
# DenseNet121 prediction
# mushroom: 29.6%
# bolete: 13.9%
# cucumber: 11.4%
# stinkhorn: 9.7%
# hen-of-the-woods: 8.7%
# DenseNet121 frame time: 0.26687052399938693
#
#
# OID/Dataset/train/Fruit/cff2073b6a9dfd40.jpg
# AlexNet prediction
# acorn: 88.2%
# fig: 8.4%
# mushroom: 1.1%
# buckeye: 0.7%
# hip: 0.6%
# AlexNet frame time: 0.0919658149996394
#
# ResNet101 prediction
# fig: 85.7%
# Granny Smith: 0.3%
# crate: 0.3%
# orange: 0.2%
# lemon: 0.2%
# ResNet101 frame time: 0.5108286269996825
#
# DenseNet121 prediction
# fig: 44.9%
# jackfruit: 12.2%
# mushroom: 9.5%
# acorn: 6.5%
# hip: 5.4%
# DenseNet121 frame time: 0.2423899800005529
#
#
# OID/Dataset/train/Fruit/3d81c7d8acab67e2.jpg
# AlexNet prediction
# hip: 100.0%
# tick: 0.0%
# ant: 0.0%
# pomegranate: 0.0%
# weevil: 0.0%
# AlexNet frame time: 0.09718501399947854
#
# ResNet101 prediction
# hip: 48.5%
# chainlink fence: 0.9%
# birdhouse: 0.1%
# picket fence: 0.1%
# tricycle: 0.1%
# ResNet101 frame time: 0.5248499589997664
#
# DenseNet121 prediction
# hip: 70.0%
# candle: 3.9%
# chainlink fence: 2.4%
# picket fence: 2.0%
# knot: 1.2%
# DenseNet121 frame time: 0.24387746100001095
#
#
# OID/Dataset/train/Fruit/a5b53097a76d4fcf.jpg
# AlexNet prediction
# fig: 71.2%
# hip: 15.4%
# strawberry: 7.3%
# acorn: 1.3%
# cucumber: 0.8%
# AlexNet frame time: 0.07972533900010603
#
# ResNet101 prediction
# hip: 75.1%
# acorn: 1.7%
# fig: 1.4%
# lorikeet: 1.0%
# bulbul: 0.8%
# ResNet101 frame time: 0.4707435489999625
#
# DenseNet121 prediction
# hip: 40.3%
# pomegranate: 19.2%
# fig: 14.9%
# bell pepper: 11.5%
# custard apple: 5.6%
# DenseNet121 frame time: 0.27539761300067767
#
#
# OID/Dataset/train/Fruit/a7f4b96f07487cb3.jpg
# AlexNet prediction
# ptarmigan: 64.5%
# common iguana: 10.5%
# stinkhorn: 2.2%
# pot: 2.1%
# marmot: 1.8%
# AlexNet frame time: 0.08260721100032242
#
# ResNet101 prediction
# quill: 71.4%
# slug: 1.6%
# coral fungus: 0.2%
# ptarmigan: 0.2%
# chainlink fence: 0.2%
# ResNet101 frame time: 0.49163777100056905
#
# DenseNet121 prediction
# coho: 93.6%
# gar: 1.6%
# barracouta: 1.6%
# quill: 1.3%
# stinkhorn: 0.7%
# DenseNet121 frame time: 0.3358913029996984
#
#
# OID/Dataset/train/Fruit/baceff9660f9973d.jpg
# AlexNet prediction
# pomegranate: 81.4%
# bakery: 3.1%
# meat loaf: 1.8%
# sea slug: 0.9%
# fig: 0.9%
# AlexNet frame time: 0.09529361600016273
#
# ResNet101 prediction
# pomegranate: 62.1%
# orange: 6.5%
# daisy: 2.9%
# fig: 1.4%
# strawberry: 1.2%
# ResNet101 frame time: 0.531207644999995
#
# DenseNet121 prediction
# pomegranate: 96.3%
# fig: 1.1%
# strawberry: 0.7%
# bell pepper: 0.4%
# trifle: 0.4%
# DenseNet121 frame time: 0.27883676500005095
#
#
# OID/Dataset/train/Fruit/026cbd2b207902fa.jpg
# AlexNet prediction
# tray: 13.3%
# envelope: 7.7%
# chest: 6.6%
# red wine: 4.9%
# table lamp: 3.8%
# AlexNet frame time: 0.0925884110001789
#
# ResNet101 prediction
# Dungeness crab: 11.9%
# mashed potato: 6.1%
# plate: 6.0%
# bolete: 5.8%
# mushroom: 3.6%
# ResNet101 frame time: 0.5707357450000927
#
# DenseNet121 prediction
# plate: 18.1%
# refrigerator: 12.2%
# acorn squash: 9.5%
# microwave: 7.7%
# menu: 5.5%
# DenseNet121 frame time: 0.28188627200051997
#
#
# OID/Dataset/train/Fruit/eb25a2dd759fca6b.jpg
# AlexNet prediction
# grocery store: 22.8%
# amphibian: 11.3%
# orange: 8.5%
# pretzel: 6.4%
# dome: 2.7%
# AlexNet frame time: 0.09512577599980432
#
# ResNet101 prediction
# grocery store: 54.5%
# jack-o'-lantern: 2.9%
# orange: 2.2%
# rain barrel: 1.7%
# chain saw: 1.2%
# ResNet101 frame time: 0.600990632000503
#
# DenseNet121 prediction
# orange: 80.2%
# lemon: 4.6%
# barrow: 3.2%
# grocery store: 3.1%
# pomegranate: 2.5%
# DenseNet121 frame time: 0.414843608999945
